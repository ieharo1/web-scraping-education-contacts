# %%
# !pip install googlesearch-python

from googlesearch import search
import requests
from bs4 import BeautifulSoup
import re
import json
import time
from IPython.display import FileLink

def limpiar_nombre(raw_title):
    if not raw_title:
        return "Nombre no encontrado"
    nombre = raw_title.strip()

    # Eliminar textos comunes no deseados y truncar tras ciertos separadores
    nombre = re.split(r'[-–—|:•]', nombre)[0]
    nombre = re.sub(r'\b(contacto|contactos|página oficial|home|portal|web|site|oficial)\b', '', nombre, flags=re.I)
    nombre = re.sub(r'\d{1,4}[\s,.-]*[a-zA-Z]*', '', nombre)
    nombre = nombre.strip()

    # Capitalizar cada palabra
    nombre = ' '.join(w.capitalize() for w in nombre.split())

    if not nombre:
        return "Nombre no encontrado"
    return nombre

busquedas = [
  "contacto correo colegio fiscal ecuador",
    "escuela pública contacto email ecuador",
    "colegio municipal ecuador email de contacto",
    "unidad educativa católica ecuador correo",
    "colegio bilingüe contacto correo ecuador",
    "colegio laico ecuador email oficial",
    "escuela técnica ecuador correo contacto",
    "colegio nacional ecuador correo electrónico",
    "colegios rurales contacto email ecuador",
    "colegio privado cristiano ecuador correo",
    "colegios de guayaquil email de contacto",
    "colegios de quito email contacto oficial",
    "instituciones educativas ecuador correo oficial",
    "colegios con página web ecuador email",
    "unidad educativa particular con correo ecuador",
    "colegio con email institucional ecuador",
    "escuelas bilingües ecuador contacto correo",
    "colegios de bachillerato ecuador email",
    "colegios técnicos ecuador contacto correo",
    "institución educativa rural ecuador email contacto",
    "colegio parroquial ecuador correo electrónico",
    "colegio privado bilingüe ecuador email contacto",
    "colegios con correo oficial quito y guayaquil",
    "escuelas fiscales ecuador contacto email",
    "colegios con correo institucional en ecuador",
]

resultados = []
correos_vistos = set()
MAX_RESULTADOS = 1000

for query in busquedas:
    print(f"Buscando: {query}")
    try:
        for url in search(query, num_results=20, lang="es"):
            if len(resultados) >= MAX_RESULTADOS:
                break
            try:
                res = requests.get(url, timeout=10)
                res.raise_for_status()
                soup = BeautifulSoup(res.text, "html.parser")
                texto = soup.get_text(separator=' ')
                # Extraer solo correos terminados en .edu.ec
                correos_raw = re.findall(r"[a-zA-Z0-9._%+-]+@[a-zA-Z0-9.-]+\.(edu\.ec)", texto, flags=re.I)
                correos = set(m.group(0) if hasattr(m,'group') else m for m in re.finditer(r"[a-zA-Z0-9._%+-]+@[a-zA-Z0-9.-]+\.(edu\.ec)", texto, flags=re.I))
                correos = {c.group(0).lower() for c in re.finditer(r"[a-zA-Z0-9._%+-]+@[a-zA-Z0-9.-]+\.edu\.ec", texto, flags=re.I)}
                correos = {c for c in correos if c not in correos_vistos}

                if not correos:
                    continue

                nombre_raw = soup.title.string if soup.title else None
                nombre = limpiar_nombre(nombre_raw)

                # Evitar que agregue si ya existe nombre igual (puedes optar si quieres unir correos)
                if any(r['nombre'] == nombre for r in resultados):
                    # Si ya está, agregar correos únicos a ese registro
                    for r in resultados:
                        if r['nombre'] == nombre:
                            nuevos = [c for c in correos if c not in r['correos'].split(', ')]
                            if nuevos:
                                r['correos'] += ', ' + ', '.join(nuevos)
                                correos_vistos.update(nuevos)
                    continue

                correos_vistos.update(correos)

                resultado = {
                    "nombre": nombre,
                    "correos": ", ".join(sorted(correos))
                }
                resultados.append(resultado)
                print(f"  + {nombre}: {len(correos)} correos")
                time.sleep(1)
            except Exception as e:
                print(f"Error en {url}: {e}")
    except Exception as e:
        print(f"Error en búsqueda '{query}': {e}")
    if len(resultados) >= MAX_RESULTADOS:
        break

print(f"\nTotal resultados: {len(resultados)}")

# Guardar en JSON
nombre_archivo = "colegios_ecuador.json"
with open(nombre_archivo, "w", encoding="utf-8") as f:
    f.write("[\n")
    for i, item in enumerate(resultados):
        coma = "," if i < len(resultados)-1 else ""
        json_str = json.dumps(item, ensure_ascii=False)
        f.write(f"  {json_str}{coma}\n")
    f.write("]\n")

print(f"\nArchivo '{nombre_archivo}' guardado con éxito.")

# Mostrar enlace para descargar en Colab
display(FileLink(nombre_archivo))

# Mostrar una muestra de resultados en consola (los 10 primeros)
print("\nEjemplo de resultados (10 primeros):")
for item in resultados[:10]:
    print(json.dumps(item, ensure_ascii=False, indent=2))
# Out:
# Collecting googlesearch-python
#   Downloading googlesearch_python-1.3.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.9 in /usr/local/lib/python3.11/dist-packages (from googlesearch-python) (4.13.4)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from googlesearch-python) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (4.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->googlesearch-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->googlesearch-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->googlesearch-python) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->googlesearch-python) (2025.6.15)
# Downloading googlesearch_python-1.3.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: googlesearch-python
# Successfully installed googlesearch-python-1.3.0
# Buscando: contacto correo colegio fiscal ecuador
# Error en https://www.gob.ec/gaddmq/tramites/inscripcion-institucion-educativa-municipal-ordinaria: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://educarecuador.gob.ec/: HTTPSConnectionPool(host='educarecuador.gob.ec', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fee50f790>, 'Connection to educarecuador.gob.ec timed out. (connect timeout=10)'))
# Error en https://www.gob.ec/mineduc/tramites/pase-transferencia-estudiantes-instituciones-educativas-fiscales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.educarecuador.gob.ec/anexos/correo/manual-uso-correo.pdf: HTTPSConnectionPool(host='www.educarecuador.gob.ec', port=443): Max retries exceeded with url: /anexos/correo/manual-uso-correo.pdf (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fee4d3cd0>, 'Connection to www.educarecuador.gob.ec timed out. (connect timeout=10)'))
#   + Colegio San Gabriel: 1 correos
#   + ► Correo Institucional Mail.educacion.gob.ec Outlook: 2 correos
# Error en https://www.fiscalia.gob.ec/transparencia/2017/septiembre/b1/literal-b1-directorio-de-la-institucion.pdf: 403 Client Error: Forbidden for url: https://www.fiscalia.gob.ec/transparencia/2017/septiembre/b1/literal-b1-directorio-de-la-institucion.pdf
# Error en https://www.dpe.gob.ec/: HTTPSConnectionPool(host='www.dpe.gob.ec', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fee015450>, 'Connection to www.dpe.gob.ec timed out. (connect timeout=10)'))
# Buscando: escuela pública contacto email ecuador
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/2019/10/directorio_telefonico-institucional-.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.gob.ec/mineduc/tramites/solicitud-acceso-informacion-publica: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.gob.ec/gaddmq/tramites/inscripcion-institucion-educativa-municipal-ordinaria: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.gobiernoelectronico.gob.ec/contactenos/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.educacionsuperior.gob.ec/contacto/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.ministeriodegobierno.gob.ec/contactos/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   + Y Ubicación: 27 correos
# Error en https://upec.edu.ec/: HTTPSConnectionPool(host='upec.edu.ec', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.ministeriodeeducacion.gob.do/: 500 Server Error: Internal Server Error for url: https://www.ministeriodeeducacion.gob.do/
# Error en https://www.presidencia.gob.ec/contacto/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.defensoria.gob.ec/: HTTPSConnectionPool(host='www.defensoria.gob.ec', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Escuela De Gobierno Uees: 3 correos
# Buscando: colegio municipal ecuador email de contacto
# Error en https://www.gob.ec/gad-carmen/tramites/educacion-colegio-municipal: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://educacion.quito.gob.ec/unidades-educativas-municipales/: HTTPSConnectionPool(host='educacion.quito.gob.ec', port=443): Max retries exceeded with url: /unidades-educativas-municipales/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.ibarra.gob.ec/site/educacion/contactos/: 406 Client Error: Not Acceptable for url: https://www.ibarra.gob.ec/site/educacion/contactos/
# Error en https://www.gob.ec/gaddmq/tramites/inscripcion-institucion-educativa-municipal-ordinaria: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://valledelamanecer.edu.ec/contacto/: 403 Client Error: Forbidden for url: https://valledelamanecer.edu.ec/contacto/
# Error en https://educacion.quito.gob.ec/contactenos/: HTTPSConnectionPool(host='educacion.quito.gob.ec', port=443): Max retries exceeded with url: /contactenos/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.ibo.org/es/school/001492: HTTPSConnectionPool(host='www.ibo.org', port=443): Max retries exceeded with url: /es/school/001492 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://escuelaplus.com/escuelas/page/782/: 403 Client Error: Forbidden for url: https://escuelaplus.com/escuelas/page/782/
# Buscando: unidad educativa católica ecuador correo
#   + Nombre no encontrado: 1 correos
#   + La Unidad Educativa Católica “la Victoria” Y La Formación Para La Vida.: 1 correos
#   + Idiomas: 4 correos
#   + Nuestras Instituciones: 25 correos
#   + Bernardino Echeverria Ruiz: 1 correos
#   + Unidad Educativa San Agustín: 2 correos
#   + Inicio: 1 correos
# Error en https://sociedaddebeneficencia.org/unidades-educativas/: 403 Client Error: Forbidden for url: https://sociedaddebeneficencia.org/unidades-educativas/
#   + Unidad Educativa Monte Tabor Nazaret: 2 correos
# Buscando: colegio bilingüe contacto correo ecuador
# Error en https://www.uebi.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.uebi.edu.ec/
# Error en https://www.colegiomenor.edu.ec/es: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es
#   + Colegio Bilingüe En Quito: 1 correos
#   + Unidad Educativa Bilingue Surcos: 2 correos
#   + Liceo Campo Verde: 1 correos
#   + Unidad Educativa Particular Bilingüe Delfos: 1 correos
#   + Unidad Educativa El Libertador: 1 correos
# Error en https://seklosvalles.ec/contacto/: HTTPSConnectionPool(host='seklosvalles.ec', port=443): Read timed out. (read timeout=10)
# Error en https://www.uebi.edu.ec/nuestro_equipo.html: 406 Client Error: Not Acceptable for url: https://www.uebi.edu.ec/nuestro_equipo.html
# Error en https://torremar.edu.ec/: 403 Client Error: Forbidden for url: https://torremar.edu.ec/
# Buscando: colegio laico ecuador email oficial
#   + Estela: 3 correos
#   + Liceo Ortega Y Gasset: 1 correos
# Error en https://www.colegiomeres.com/: 403 Client Error: Forbidden for url: https://www.colegiomeres.com/
# Error en https://www.uleam.edu.ec/: HTTPSConnectionPool(host='www.uleam.edu.ec', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Ulvr: 1 correos
# Error en https://www.gob.ec/mineduc/tramites/pase-transferencia-estudiantes-instituciones-educativas-fiscales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.instagram.com/colegioeinsteinquito/reel/DIZoOq_Pp8h/?locale=my: 429 Client Error: Too Many Requests for url: https://www.instagram.com/accounts/login/?next=https%3A%2F%2Fwww.instagram.com%2Fcolegioeinsteinquito%2Freel%2FDIZoOq_Pp8h%2F%3Flocale%3Dmy&is_from_rle
# Buscando: escuela técnica ecuador correo contacto
#   + Contáctanos: 9 correos
# Error en https://istct.edu.ec/portal/nuevo/contacto/: HTTPSConnectionPool(host='istct.edu.ec', port=443): Max retries exceeded with url: /portal/nuevo/contacto/ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7f0fee485cd0>: Failed to resolve 'istct.edu.ec' ([Errno -2] Name or service not known)"))
#   + Escuela Politécnica Nacional: 1 correos
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/downloads/2014/09/Directorio-IES-2014.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/2019/10/directorio_telefonico-institucional-.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   + Tecnológico Argos Educación Técnica Superior En Guayaquil: 7 correos
# Error en https://twitter.com/DGAC_Ecuador/status/1545412173714935812: 400 Client Error: Bad Request for url: https://x.com/DGAC_Ecuador/status/1545412173714935812
#   + Universidad Politécnica Salesiana: 4 correos
# Buscando: colegio nacional ecuador correo electrónico
# Error en https://escuelaecuador.cl/category/estudiantes/correo-institucional/: 403 Client Error: Forbidden for url: https://escuelaecuador.cl/category/estudiantes/correo-institucional/
#   + Unidad Educativa Nacional Tena: 1 correos
# Error en https://escuelaecuador.cl/acceso-al-correo-institucional-de-los-estudiantes/: 403 Client Error: Forbidden for url: https://escuelaecuador.cl/acceso-al-correo-institucional-de-los-estudiantes/
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/downloads/2014/09/Directorio-IES-2014.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://creconcepcion.cl/contacto/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.casc.edu.ec/directorio/: HTTPSConnectionPool(host='www.casc.edu.ec', port=443): Max retries exceeded with url: /directorio/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Colegio La Moderna: 1 correos
# Buscando: colegios rurales contacto email ecuador
# Error en https://escuelaplus.com/escuelas/page/749/: 403 Client Error: Forbidden for url: https://escuelaplus.com/escuelas/page/749/
# Error en https://escuelaplus.com/escuelas/page/762/: 403 Client Error: Forbidden for url: https://escuelaplus.com/escuelas/page/762/
# Error en https://www.agricultura.gob.ec/inician-inscripciones-para-la-octava-edicion-de-la-escuela-joven-rural/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://torremar.edu.ec/labor-social-visitas-a-escuelas-rurales-2/: 403 Client Error: Forbidden for url: https://torremar.edu.ec/labor-social-visitas-a-escuelas-rurales-2/
# Error en https://familiasenruta.com/familias-crianza/visitando-una-escuelita-rural-en-ecuador/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://unsdg.un.org/es/latest/stories/un-regreso-seguro-las-clases-presenciales-en-las-zonas-rurales-de-ecuador: 403 Client Error: Forbidden for url: https://unsdg.un.org/es/latest/stories/un-regreso-seguro-las-clases-presenciales-en-las-zonas-rurales-de-ecuador
# Error en https://es.wfp.org/noticias/ecuador-santa-elena-y-wfp-apuestan-por-las-comidas-escolares-nutritivas-en-escuelas-rurales: 403 Client Error: Forbidden for url: https://es.wfp.org/noticias/ecuador-santa-elena-y-wfp-apuestan-por-las-comidas-escolares-nutritivas-en-escuelas-rurales
# Error en https://rus.ucf.edu.cu/index.php/rus/article/view/2584: HTTPSConnectionPool(host='rus.ucf.edu.cu', port=443): Max retries exceeded with url: /index.php/rus/article/view/2584 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0feddd37d0>, 'Connection to rus.ucf.edu.cu timed out. (connect timeout=10)'))
# Error en https://ecuadorverifica.org/2022/05/25/guillermo-lasso-hemos-reabierto-100-escuelas-rurales/: 406 Client Error: Not Acceptable for url: https://ecuadorverifica.org/2022/05/25/guillermo-lasso-hemos-reabierto-100-escuelas-rurales/
# Error en https://ecuadorchequea.com/11-escuelas-rurales-de-imbabura-reciben-progresivamente-a-sus-estudiantes/page/69/?et_blog: 406 Client Error: Not Acceptable for url: https://ecuadorchequea.com/11-escuelas-rurales-de-imbabura-reciben-progresivamente-a-sus-estudiantes/page/69/?et_blog
# Error en https://es.wfp.org/noticias/el-programa-mundial-de-alimentos-inicia-la-entrega-de-comidas-escolares-en-escuelas: 403 Client Error: Forbidden for url: https://es.wfp.org/noticias/el-programa-mundial-de-alimentos-inicia-la-entrega-de-comidas-escolares-en-escuelas
# Error en https://grupogeard.com/ec/blog/educacion/educacion-rural-importancia-desarrollo-sistema-educativo/: 403 Client Error: Forbidden for url: https://grupogeard.com/ec/blog/educacion/educacion-rural-importancia-desarrollo-sistema-educativo/
# Error en https://www.revistasocialfronteriza.com/ojs/index.php/rev/article/view/66: 403 Client Error: Forbidden for url: https://www.revistasocialfronteriza.com/ojs/index.php/rev/article/view/66
# Buscando: colegio privado cristiano ecuador correo
#   + Colegio Cristiano En Quito / Colegio Particular En Quito: 1 correos
#   + La Salle Ambato: 1 correos
# Error en https://www.uebi.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.uebi.edu.ec/
# Error en https://www.ministeriodeeducacion.gob.do/media/banners/3978bbfcbdc28067d642a7e8d5944bdf84ca2de8centros-educativos-privados-y-relacion-de-centros-publicos-con-mas-de-200-alumnos-entre-5-y-11-anospdf.pdf: HTTPSConnectionPool(host='www.ministeriodeeducacion.gob.do', port=443): Read timed out. (read timeout=10)
# Buscando: colegios de guayaquil email de contacto
# Error en https://alemanhumboldt.edu.ec/contactos/: 403 Client Error: Forbidden for url: https://alemanhumboldt.edu.ec/contactos/
# Error en https://sekguayaquil.com/contacto/: HTTPSConnectionPool(host='sekguayaquil.com', port=443): Read timed out. (read timeout=10)
# Error en https://www.logosacademy.edu.ec/logos-academy-contacto-guayaquil/: 403 Client Error: Forbidden for url: https://www.logosacademy.edu.ec/logos-academy-contacto-guayaquil/
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
# Error en https://www.santistevan.edu.ec/contacto: HTTPSConnectionPool(host='www.santistevan.edu.ec', port=443): Max retries exceeded with url: /contacto (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Escuela Y Colegio Femenino Espíritu Santo: 2 correos
# Error en https://sekguayaquil.com/: HTTPSConnectionPool(host='sekguayaquil.com', port=443): Read timed out. (read timeout=10)
#   + Colegio Letras Y Vida: 2 correos
#   + Colegio Nuevo Mundo: 1 correos
# Buscando: colegios de quito email contacto oficial
# Error en https://educacion.quito.gob.ec/unidades-educativas-municipales/: HTTPSConnectionPool(host='educacion.quito.gob.ec', port=443): Max retries exceeded with url: /unidades-educativas-municipales/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.colegiosquito.com/directorio-colegios-quito/: 403 Client Error: Forbidden for url: https://www.colegiosquito.com/directorio-colegios-quito/
# Error en https://www4.quito.gob.ec/: HTTPSConnectionPool(host='www4.quito.gob.ec', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Colegio Johannes Kepler: 1 correos
#   + Colegio Francã©s: 1 correos
#   + Ue: 1 correos
#   + Colegio Andino: 2 correos
# Buscando: instituciones educativas ecuador correo oficial
# Error en https://www.educarecuador.gob.ec/anexos/correo/manual-uso-correo.pdf: HTTPSConnectionPool(host='www.educarecuador.gob.ec', port=443): Max retries exceeded with url: /anexos/correo/manual-uso-correo.pdf (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fed6eddd0>, 'Connection to www.educarecuador.gob.ec timed out. (connect timeout=10)'))
# Error en https://www.educacionsuperior.gob.ec/directorio-de-instituciones-de-educacion-superior/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://consultasecuador.com/blog/ver/acceso-al-correo-institucional-de-ministerio-de-educacion: 403 Client Error: Forbidden for url: https://consultasecuador.com/blog/ver/acceso-al-correo-institucional-de-ministerio-de-educacion
# Error en https://www.tramitesbasicos.com/correo-institucional-ministerio-educacion/: 403 Client Error: Forbidden for url: https://www.tramitesbasicos.com/correo-institucional-ministerio-educacion/
# Error en https://educarecuador.gob.ec/: HTTPSConnectionPool(host='educarecuador.gob.ec', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fec86b790>, 'Connection to educarecuador.gob.ec timed out. (connect timeout=10)'))
#   + ▷ Iniciar Sesión Outlook【correo@educacion.gob.ec】: 1 correos
# Error en https://educacion.quito.gob.ec/: HTTPSConnectionPool(host='educacion.quito.gob.ec', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.gob.ec/mineduc/tramites/emision-autorizacion-creacion-funcionamiento-instituciones-educativas-particulares-fiscomisionales-municipales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.ministeriodeeducacion.gob.do/: HTTPSConnectionPool(host='www.ministeriodeeducacion.gob.do', port=443): Read timed out. (read timeout=10)
# Buscando: colegios con página web ecuador email
# Error en https://www.colegiosquito.com/directorio-colegios-quito/: 403 Client Error: Forbidden for url: https://www.colegiosquito.com/directorio-colegios-quito/
# Error en https://sekguayaquil.com/: HTTPSConnectionPool(host='sekguayaquil.com', port=443): Read timed out. (read timeout=10)
#   + Colegio Terranova: 1 correos
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
# Error en https://pachamama.edu.ec/: 406 Client Error: Not Acceptable for url: https://pachamama.edu.ec/
# Error en https://www.liceointernacional.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.liceointernacional.edu.ec/
#   + Shakespeare School: 1 correos
# Error en https://www.colegiomenor.edu.ec/es: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es
# Error en https://crearonline.edu.ec/: 406 Client Error: Not Acceptable for url: https://crearonline.edu.ec/
# Buscando: unidad educativa particular con correo ecuador
#   + Unidad Educativa Particular Verbo > Inicio: 1 correos
# Error en https://cedfi.com.ec/: 406 Client Error: Not Acceptable for url: https://cedfi.com.ec/
# Error en https://ladolorosa.edu.ec/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://praga.edu.ec/: 403 Client Error: Forbidden for url: https://praga.edu.ec/
# Error en https://www.uneindelpacifico.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.uneindelpacifico.edu.ec/
#   + Unidad Educativa Particular Porvenir: 1 correos
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
#   + Unidad Educativa Particular "julio María Matovelle"": 1 correos
#   + Unidad Educativa La Asunción: 1 correos
#   + Contáctenos: 1 correos
#   + Redemptio: 1 correos
# Buscando: colegio con email institucional ecuador
# Error en /search?num=22: Invalid URL '/search?num=22': No scheme supplied. Perhaps you meant https:///search?num=22?
# Error en https://adistancia.educacion.gob.ec/consulta-cuenta-de-correo-electronico-convocatoria-12/: HTTPSConnectionPool(host='adistancia.educacion.gob.ec', port=443): Max retries exceeded with url: /consulta-cuenta-de-correo-electronico-convocatoria-12/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fee456290>, 'Connection to adistancia.educacion.gob.ec timed out. (connect timeout=10)'))
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
# Error en https://www.casc.edu.ec/directorio/: HTTPSConnectionPool(host='www.casc.edu.ec', port=443): Max retries exceeded with url: /directorio/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://ilinizas.edu.ec/: 406 Client Error: Not Acceptable for url: https://ilinizas.edu.ec/
# Buscando: escuelas bilingües ecuador contacto correo
# Error en https://seklosvalles.ec/contacto/: HTTPSConnectionPool(host='seklosvalles.ec', port=443): Read timed out. (read timeout=10)
# Error en https://sekquito.com/: 500 Server Error: Internal Server Error for url: https://sekquito.com/
# Error en https://www.uebi.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.uebi.edu.ec/
# Error en https://torremar.edu.ec/: 403 Client Error: Forbidden for url: https://torremar.edu.ec/
# Error en https://www.colegiomenor.edu.ec/es: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es
# Buscando: colegios de bachillerato ecuador email
#   + Ue San José: 1 correos
#   + Contácto: 2 correos
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
# Buscando: colegios técnicos ecuador contacto correo
# Error en https://istct.edu.ec/portal/nuevo/contacto/: HTTPSConnectionPool(host='istct.edu.ec', port=443): Max retries exceeded with url: /portal/nuevo/contacto/ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7f0fed610710>: Failed to resolve 'istct.edu.ec' ([Errno -2] Name or service not known)"))
# Error en https://www.lusha.com/business/67c8127bfdfc958f/: 403 Client Error: Forbidden for url: https://www.lusha.com/business/67c8127bfdfc958f/
# Error en https://uets.edu.ec/: 406 Client Error: Not Acceptable for url: https://uets.edu.ec/
# Error en https://www.colegiomenor.edu.ec/es/quito/admissions/inquiry: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/quito/admissions/inquiry
# Error en https://www.educacionbogota.edu.co/portal_institucional/sites/default/files/inline-files/2022/Directorio-Colegios-Distritales-y-Direcciones-Locales-16012024.xlsx: HTTPSConnectionPool(host='www.educacionbogota.edu.co', port=443): Max retries exceeded with url: /portal_institucional/sites/default/files/inline-files/2022/Directorio-Colegios-Distritales-y-Direcciones-Locales-16012024.xlsx (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fecfca490>, 'Connection to www.educacionbogota.edu.co timed out. (connect timeout=10)'))
# Error en https://www.comunicacion.gob.ec/bachillerato-tecnico-productivo-ofrece-a-los-jovenes-un-mecanismo-de-sustento/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Buscando: institución educativa rural ecuador email contacto
# Error en https://www.cali.gov.co/educacion/publicaciones/159761/directorio-ieo/: 403 Client Error: Forbidden for url: https://www.cali.gov.co/educacion/publicaciones/159761/directorio-ieo/
# Error en http://scielo.sld.cu/scielo.php?script=sci_arttext&pid=S1990-86442018000200026: HTTPConnectionPool(host='scielo.sld.cu', port=80): Max retries exceeded with url: /scielo.php?script=sci_arttext&pid=S1990-86442018000200026 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f0fed334390>, 'Connection to scielo.sld.cu timed out. (connect timeout=10)'))
# Error en https://polodelconocimiento.com/ojs/index.php/es/article/view/6138/html: HTTPSConnectionPool(host='polodelconocimiento.com', port=443): Read timed out. (read timeout=10)
# Error en https://grupogeard.com/ec/blog/educacion/educacion-rural-importancia-desarrollo-sistema-educativo/: 403 Client Error: Forbidden for url: https://grupogeard.com/ec/blog/educacion/educacion-rural-importancia-desarrollo-sistema-educativo/
# Error en https://www.unicef.org/ecuador/comunicados-prensa/los-ni%C3%B1os-no-pueden-seguir-sin-ir-la-escuela-afirma-unicef: 403 Client Error: Forbidden for url: https://www.unicef.org/ecuador/comunicados-prensa/los-ni%C3%B1os-no-pueden-seguir-sin-ir-la-escuela-afirma-unicef
# Error en https://escuelaplus.com/escuelas/page/749/: 403 Client Error: Forbidden for url: https://escuelaplus.com/escuelas/page/749/
# Error en https://revistapublicando.org/revista/index.php/crv/article/view/2221/2483: 406 Client Error: Not Acceptable for url: https://revistapublicando.org/revista/index.php/crv/article/view/2221/2483
# Buscando: colegio parroquial ecuador correo electrónico
# Error en https://losandes.gob.ec/carchi/correo-institucional/: 500 Server Error: Internal Server Error for url: https://losandes.gob.ec/carchi/correo-institucional/
# Error en https://gobierno.gadcalderon.gob.ec/wp-content/uploads/2020/06/DIRECTORIO-TELEFONICO-DE-LA-INSTITUCI%C3%93N-horizontal.pdf: 403 Client Error: Forbidden for url: https://gobierno.gadcalderon.gob.ec/wp-content/uploads/2020/06/DIRECTORIO-TELEFONICO-DE-LA-INSTITUCI%C3%93N-horizontal.pdf
# Error en https://www.funcionjudicial.gob.ec/centros-mediacion-aprobados/: HTTPSConnectionPool(host='www.funcionjudicial.gob.ec', port=443): Max retries exceeded with url: /centros-mediacion-aprobados/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fec8e8c10>, 'Connection to www.funcionjudicial.gob.ec timed out. (connect timeout=10)'))
# Buscando: colegio privado bilingüe ecuador email contacto
# Error en https://www.colegiomenor.edu.ec/es: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es
# Error en https://sekguayaquil.com/: HTTPSConnectionPool(host='sekguayaquil.com', port=443): Read timed out. (read timeout=10)
# Error en https://www.uebi.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.uebi.edu.ec/
#   + Colegio Privado Isaac Newton Al Norte De Quito: 5 correos
#   + Kruger School: 1 correos
# Error en https://www.williamcaxton.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.williamcaxton.edu.ec/
# Buscando: colegios con correo oficial quito y guayaquil
# Error en https://sekguayaquil.com/: HTTPSConnectionPool(host='sekguayaquil.com', port=443): Read timed out. (read timeout=10)
# Error en https://www.colegiomenor.edu.ec/es/quito: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/quito
# Buscando: escuelas fiscales ecuador contacto email
# Error en https://www.gob.ec/mineduc/tramites/inscripcion-al-sistema-educativo-fiscal: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.gob.ec/mineduc/tramites/promocion-estudiantes-instituciones-educativas-fiscales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://educarecuador.gob.ec/juntos/costa-traslados/: HTTPSConnectionPool(host='educarecuador.gob.ec', port=443): Max retries exceeded with url: /juntos/costa-traslados/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fee5e9c90>, 'Connection to educarecuador.gob.ec timed out. (connect timeout=10)'))
# Error en https://educarecuador.gob.ec/: HTTPSConnectionPool(host='educarecuador.gob.ec', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fed489bd0>, 'Connection to educarecuador.gob.ec timed out. (connect timeout=10)'))
# Error en https://www.deporte.gob.ec/ministerio-del-deporte-activa-escuelas-fiscales/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.finanzas.gob.ec/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://escuelaplus.com/escuelas/page/757/: 403 Client Error: Forbidden for url: https://escuelaplus.com/escuelas/page/757/
# Error en https://www.dpe.gob.ec/: HTTPSConnectionPool(host='www.dpe.gob.ec', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fec8b6e10>, 'Connection to www.dpe.gob.ec timed out. (connect timeout=10)'))
# Error en https://www.evaluacion.gob.ec/wp-content/uploads/downloads/2024/04/Listado-de-IE-SEST-Sierra-Amazoni%CC%81a-2024.pdf: HTTPSConnectionPool(host='www.evaluacion.gob.ec', port=443): Max retries exceeded with url: /wp-content/uploads/downloads/2024/04/Listado-de-IE-SEST-Sierra-Amazoni%CC%81a-2024.pdf (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fed876210>, 'Connection to www.evaluacion.gob.ec timed out. (connect timeout=10)'))
# Buscando: colegios con correo institucional en ecuador
# Error en https://adistancia.educacion.gob.ec/consulta-cuenta-de-correo-electronico-convocatoria-12/: HTTPSConnectionPool(host='adistancia.educacion.gob.ec', port=443): Max retries exceeded with url: /consulta-cuenta-de-correo-electronico-convocatoria-12/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fedfd0990>, 'Connection to adistancia.educacion.gob.ec timed out. (connect timeout=10)'))
# Error en https://www.educarecuador.gob.ec/anexos/correo/manual-uso-correo.pdf: HTTPSConnectionPool(host='www.educarecuador.gob.ec', port=443): Max retries exceeded with url: /anexos/correo/manual-uso-correo.pdf (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f0fee49f890>, 'Connection to www.educarecuador.gob.ec timed out. (connect timeout=10)'))
# Error en https://www.educacionsuperior.gob.ec/directorio-de-instituciones-de-educacion-superior/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://escuelaecuador.cl/acceso-al-correo-institucional-de-los-estudiantes/: 403 Client Error: Forbidden for url: https://escuelaecuador.cl/acceso-al-correo-institucional-de-los-estudiantes/
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/downloads/2014/09/Directorio-IES-2014.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://educacion.quito.gob.ec/unidades-educativas-municipales/: HTTPSConnectionPool(host='educacion.quito.gob.ec', port=443): Max retries exceeded with url: /unidades-educativas-municipales/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Correo@estudiantes.edu.ec: 1 correos
#
# Total resultados: 49
#
# Archivo 'colegios_ecuador.json' guardado con éxito.
# /content/colegios_ecuador.json
# Ejemplo de resultados (10 primeros):
# {
#   "nombre": "Colegio San Gabriel",
#   "correos": "contacto@csgabriel.edu.ec"
# }
# {
#   "nombre": "► Correo Institucional Mail.educacion.gob.ec Outlook",
#   "correos": "marta.bonilla@estudiantes.edu.ec, nombre.apellido@estudiantes.edu.ec"
# }
# {
#   "nombre": "Y Ubicación",
#   "correos": "adquisiciones@caq.edu.ec, almacen@caq.edu.ec, analista.compensaciones@caq.edu.ec, analista.seleccion@caq.edu.ec, apple.helpdesk@caq.edu.ec, asistente.gerencia@caq.edu.ec, asistente.recgeneral@caq.edu.ec, asistente.secundaria@caq.edu.ec, biblioteca@caq.edu.ec, cobranzas@caq.edu.ec, content.manager@caq.edu.ec, coordinador.transporte@caq.edu.ec, dpto.medico@caq.edu.ec, enfermeria.kinder@caq.edu.ec, extracurricular@caq.edu.ec, help.desk@caq.edu.ec, info@caq.edu.ec, jefe.comunicacion@caq.edu.ec, jefe.personal@caq.edu.ec, jefe.seguridad@caq.edu.ec, musica_cultura@caq.edu.ec, recepcion@caq.edu.ec, secretaria.kinder@caq.edu.ec, secretaria.primaria@caq.edu.ec, secretaria.secundaria@caq.edu.ec, seleccion@caq.edu.ec, tecnico.helpdesk@caq.edu.ec"
# }
# {
#   "nombre": "Escuela De Gobierno Uees",
#   "correos": "admisiones@uees.edu.ec, andreaarias@uees.edu.ec, hyepezm@uees.edu.ec"
# }
# {
#   "nombre": "Nombre no encontrado",
#   "correos": "info@ucacue.edu.ec, info.educacion@cu.ucsg.edu.ec, info.cine@cu.ucsg.edu.ec, info.farquitectura@cu.ucsg.edu.ec, info.artesyhum@cu.ucsg.edu.ec, info.salud@cu.ucsg.edu.ec, info.economia@cu.ucsg.edu.ec, info.administracion@cu.ucsg.edu.ec, info@cu.ucsg.edu.ec, info.derecho@cu.ucsg.edu.ec, info.animaciondigital@cu.ucsg.edu.ec, info.tecnica@cu.ucsg.edu.ec, info.filosofia@cu.ucsg.edu.ec, club.ciencias@cu.ucsg.edu.ec, info.pedagogaidioma@cu.ucsg.edu.ec, info.electricidad@cu.ucsg.edu.ec, info.psic-organizacion@cu.ucsg.edu.ec, info.turismo@cu.ucsg.edu.ec, info.medicina@cu.ucsg.edu.ec, ventas.educontinua@cu.ucsg.edu.ec, admisiones@cu.ucsg.edu.ec, info.computacion@cu.ucsg.edu.ec, info.comercio@cu.ucsg.edu.ec, info.artesmusicales@cu.ucsg.edu.ec, info.psic-clinica@cu.ucsg.edu.ec, info.comercioexterior@cu.ucsg.edu.ec, alonso.veloz@cu.ucsg.edu.ec, info.veterinaria@cu.ucsg.edu.ec, info.civil@cu.ucsg.edu.ec, info.automatizacion@cu.ucsg.edu.ec, info.enfermeria@cu.ucsg.edu.ec, info.diseinterior@cu.ucsg.edu.ec, info.agropecuaria@cu.ucsg.edu.ec, info.aprvideosjuegos@cu.ucsg.edu.ec, vip@cu.ucsg.edu.ec, info.comunicacion@cu.ucsg.edu.ec, info.mercadotecnia@cu.ucsg.edu.ec, educacion.continua@cu.ucsg.edu.ec, info.telecomunicacion@cu.ucsg.edu.ec, info.fisioterapia@cu.ucsg.edu.ec, info.fee@cu.ucsg.edu.ec, info.negocios@cu.ucsg.edu.ec, info.arquitectura@cu.ucsg.edu.ec, info.ingenieria@cu.ucsg.edu.ec, info.auditoria@cu.ucsg.edu.ec, info.diseniografico@cu.ucsg.edu.ec, info.nutridiete@cu.ucsg.edu.ec, info.agroindustria@cu.ucsg.edu.ec, info.odontologico@cu.ucsg.edu.ec, info.trabajosocial@cu.ucsg.edu.ec, diogenes.diaz@cu.ucsg.edu.ec, admisiones@williamthomsoninternacional.edu.ec, colecturia@colegiodeamerica.edu.ec, secretaria@colegiodeamerica.edu.ec, trabajosocial@colegiodeamerica.edu.ec, inspeccion@colegiodeamerica.edu.ec, vvaca@colegiodeliga.edu.ec, cbonilla@colegiodeliga.edu.ec, cflores@colegiodeliga.edu.ec, fcabascango@colegiodeliga.edu.ec, secretariageneral@colegiodeliga.edu.ec, mesadeayuda@colegiodeliga.edu.ec, jnaranjo@colegiodeliga.edu.ec, recepcion@sscc.edu.ec, n@sscc.edu.ec, ffioravanti@email.balandra.edu.ec, info@email.balandra.edu.ec, admissions@britishschoolquito.edu.ec, coordinacion@aseccbi.edu.ec, info@thomasmore.edu.ec"
# }
# {
#   "nombre": "La Unidad Educativa Católica “la Victoria” Y La Formación Para La Vida.",
#   "correos": "secretaria@lavictoria.edu.ec"
# }
# {
#   "nombre": "Idiomas",
#   "correos": "fvcarvajal@puce.edu.ec, japaredesb@puce.edu.ec, kacosta418@puce.edu.ec, vpena794@puce.edu.ec"
# }
# {
#   "nombre": "Nuestras Instituciones",
#   "correos": "administracion2@cbecheverria.edu.ec, administracion@arzube.edu.ec, administracion@bgarelli.edu.ec, administracion@cbecheverria.edu.ec, administracion@doloressopena.edu.ec, administracion@jmriera.edu.ec, administracion@juanbosco.edu.ec, administracion@juandiego.edu.ec, administracion@laconsolata.edu.ec, administracion@lascumbres.edu.ec, administracion@mnastudillo.edu.ec, administracion@narcisadejesus.edu.ec, administracion@nsmontebello.edu.ec, administracion@nssabiduria.edu.ec, administracion@prolucianas.edu.ec, administracion@rcushing.edu.ec, administracion@sanesteban.edu.ec, administracion@sanjoaquin.edu.ec, administracion@sfjavier.edu.ec, administracion@sfnazareth.edu.ec, administracion@stomas.edu.ec, administracion@uesantamaria.edu.ec, administracion@uespra.edu.ec, administracion@vdelcisne.edu.ec, administracionescuela@starosa.edu.ec"
# }
# {
#   "nombre": "Bernardino Echeverria Ruiz",
#   "correos": "bernardino@cbecheverria.edu.ec"
# }
# {
#   "nombre": "Unidad Educativa San Agustín",
#   "correos": "admisiones@sanagustin.edu.ec, info@sanagustin.edu.ec"
# }
