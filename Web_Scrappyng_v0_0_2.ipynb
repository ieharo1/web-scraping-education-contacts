# %%
# !pip install googlesearch-python

from googlesearch import search
import requests
from bs4 import BeautifulSoup
import re
import json
import time
from IPython.display import FileLink

def limpiar_nombre(raw_title):
    if not raw_title:
        return "Nombre no encontrado"
    nombre = raw_title.strip()

    # Eliminar textos comunes no deseados y truncar tras ciertos separadores
    nombre = re.split(r'[-–—|:•]', nombre)[0]
    nombre = re.sub(r'\b(contacto|contactos|página oficial|home|portal|web|site|oficial)\b', '', nombre, flags=re.I)
    nombre = re.sub(r'\d{1,4}[\s,.-]*[a-zA-Z]*', '', nombre)
    nombre = nombre.strip()

    # Capitalizar cada palabra
    nombre = ' '.join(w.capitalize() for w in nombre.split())

    if not nombre:
        return "Nombre no encontrado"
    return nombre

busquedas = [
  "colegios en ecuador contacto email",
    "escuelas en ecuador correo de contacto",
    "unidad educativa ecuador email",
    "colegio particular ecuador correo",
    "colegio oficial ecuador contacto email",
    "institución educativa ecuador email",
    "colegios bilingües ecuador contacto",
    "colegio católico ecuador correo electrónico",
    "colegio privado ecuador contacto",
    "escuela pública ecuador correo",
    "colegios urbanos ecuador email",
    "colegios rurales ecuador email contacto",
    "unidad educativa particular ecuador email",
    "colegios con email de contacto ecuador",
    "escuelas con email de contacto ecuador",
    "colegios bilingües privados ecuador correo",
    "colegio secundario ecuador contacto email",
    "colegio primaria ecuador email",
    "colegio técnico ecuador correo electrónico",
    "colegio religioso ecuador contacto email",
    "colegios oficiales ecuador email",
    "colegios católicos ecuador correo electrónico",
    "colegios privados en quito email",
    "colegios privados en guayaquil contacto email",
    "unidad educativa rural ecuador correo electrónico",
    "colegio con correo oficial ecuador",
    "institución educativa con email contacto ecuador",
]

resultados = []
correos_vistos = set()
MAX_RESULTADOS = 1000

for query in busquedas:
    print(f"Buscando: {query}")
    try:
        for url in search(query, num_results=20, lang="es"):
            if len(resultados) >= MAX_RESULTADOS:
                break
            try:
                res = requests.get(url, timeout=10)
                res.raise_for_status()
                soup = BeautifulSoup(res.text, "html.parser")
                texto = soup.get_text(separator=' ')
                # Extraer solo correos terminados en .edu.ec
                correos_raw = re.findall(r"[a-zA-Z0-9._%+-]+@[a-zA-Z0-9.-]+\.(edu\.ec)", texto, flags=re.I)
                correos = set(m.group(0) if hasattr(m,'group') else m for m in re.finditer(r"[a-zA-Z0-9._%+-]+@[a-zA-Z0-9.-]+\.(edu\.ec)", texto, flags=re.I))
                correos = {c.group(0).lower() for c in re.finditer(r"[a-zA-Z0-9._%+-]+@[a-zA-Z0-9.-]+\.edu\.ec", texto, flags=re.I)}
                correos = {c for c in correos if c not in correos_vistos}

                if not correos:
                    continue

                nombre_raw = soup.title.string if soup.title else None
                nombre = limpiar_nombre(nombre_raw)

                # Evitar que agregue si ya existe nombre igual (puedes optar si quieres unir correos)
                if any(r['nombre'] == nombre for r in resultados):
                    # Si ya está, agregar correos únicos a ese registro
                    for r in resultados:
                        if r['nombre'] == nombre:
                            nuevos = [c for c in correos if c not in r['correos'].split(', ')]
                            if nuevos:
                                r['correos'] += ', ' + ', '.join(nuevos)
                                correos_vistos.update(nuevos)
                    continue

                correos_vistos.update(correos)

                resultado = {
                    "nombre": nombre,
                    "correos": ", ".join(sorted(correos))
                }
                resultados.append(resultado)
                print(f"  + {nombre}: {len(correos)} correos")
                time.sleep(1)
            except Exception as e:
                print(f"Error en {url}: {e}")
    except Exception as e:
        print(f"Error en búsqueda '{query}': {e}")
    if len(resultados) >= MAX_RESULTADOS:
        break

print(f"\nTotal resultados: {len(resultados)}")

# Guardar en JSON
nombre_archivo = "colegios_ecuador.json"
with open(nombre_archivo, "w", encoding="utf-8") as f:
    f.write("[\n")
    for i, item in enumerate(resultados):
        coma = "," if i < len(resultados)-1 else ""
        json_str = json.dumps(item, ensure_ascii=False)
        f.write(f"  {json_str}{coma}\n")
    f.write("]\n")

print(f"\nArchivo '{nombre_archivo}' guardado con éxito.")

# Mostrar enlace para descargar en Colab
display(FileLink(nombre_archivo))

# Mostrar una muestra de resultados en consola (los 10 primeros)
print("\nEjemplo de resultados (10 primeros):")
for item in resultados[:10]:
    print(json.dumps(item, ensure_ascii=False, indent=2))
# Out:
# Collecting googlesearch-python
#   Downloading googlesearch_python-1.3.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.9 in /usr/local/lib/python3.11/dist-packages (from googlesearch-python) (4.13.4)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from googlesearch-python) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (4.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->googlesearch-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->googlesearch-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->googlesearch-python) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->googlesearch-python) (2025.6.15)
# Downloading googlesearch_python-1.3.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: googlesearch-python
# Successfully installed googlesearch-python-1.3.0
# Buscando: colegios en ecuador contacto email
#   + Nombre no encontrado: 7 correos
#   + Y Ubicación: 27 correos
# Error en https://www.casc.edu.ec/directorio/: HTTPSConnectionPool(host='www.casc.edu.ec', port=443): Max retries exceeded with url: /directorio/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Contáctenos: 1 correos
# Error en https://www.colegiomenor.edu.ec/es/contact-us: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/contact-us
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/downloads/2014/09/Directorio-IES-2014.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://becquerel.edu.ec/contacto/: 403 Client Error: Forbidden for url: https://becquerel.edu.ec/contacto/
# Error en https://www.isaacnewton.edu.ec/contacto/: 403 Client Error: Forbidden for url: https://www.isaacnewton.edu.ec/contacto/
# Error en https://www.ibo.org/en/school/000566: HTTPSConnectionPool(host='www.ibo.org', port=443): Max retries exceeded with url: /en/school/000566 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.colegiomenor.edu.ec/es/quito/admissions/inquiry: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/quito/admissions/inquiry
# Buscando: escuelas en ecuador correo de contacto
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/downloads/2014/09/Directorio-IES-2014.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://educacion.quito.gob.ec/contactenos/: HTTPSConnectionPool(host='educacion.quito.gob.ec', port=443): Max retries exceeded with url: /contactenos/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://sekquito.com/contacto/: HTTPSConnectionPool(host='sekquito.com', port=443): Read timed out. (read timeout=10)
#   + Contact Us: 9 correos
# Error en https://www.educacionsuperior.gob.ec/directorio-de-instituciones-de-educacion-superior/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://seklosvalles.ec/contacto/: HTTPSConnectionPool(host='seklosvalles.ec', port=443): Read timed out. (read timeout=10)
# Error en https://olivosschool.com/contacto-olivos-school-escuela-valle-de-los-chillos/: 412 Client Error: Precondition Failed for url: https://olivosschool.com/contacto-olivos-school-escuela-valle-de-los-chillos/
# Error en https://www.colegiomenor.edu.ec/es/contact-us: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/contact-us
#   + Colegio Terranova: 1 correos
#   + Escuela Politécnica Nacional: 1 correos
# Buscando: unidad educativa ecuador email
# Error en https://www.uneindelpacifico.edu.ec/contacto/: 406 Client Error: Not Acceptable for url: https://www.uneindelpacifico.edu.ec/contacto/
#   + Https: 1 correos
# Error en https://ladolorosa.edu.ec/contacto/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   + Ue San José: 1 correos
#   + Unidad Educativa Santo Domingo De Guzmán: 1 correos
# Error en https://www.cristorey.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.cristorey.edu.ec/
#   + Unidad Educativa A Distancia República De Argentina: 1 correos
# Buscando: colegio particular ecuador correo
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
#   + Kruger School: 1 correos
# Error en https://ilinizas.edu.ec/: 406 Client Error: Not Acceptable for url: https://ilinizas.edu.ec/
#   + Colegio Francã©s: 1 correos
# Error en https://ladolorosa.edu.ec/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   + Nuestras Instituciones: 25 correos
#   + Unidad Educativa Particular Bilingüe Delfos: 1 correos
#   + Colegio Nuevo Mundo: 1 correos
#   + Redemptio: 1 correos
# Buscando: colegio oficial ecuador contacto email
# Error en https://sekquito.com/contacto/: HTTPSConnectionPool(host='sekquito.com', port=443): Read timed out. (read timeout=10)
# Error en https://www.cancilleria.gob.ec/newyork/2021/03/09/contactenos/: HTTPSConnectionPool(host='www.cancilleria.gob.ec', port=443): Max retries exceeded with url: /newyork/2021/03/09/contactenos/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://creconcepcion.cl/contacto/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.ecp.ec/contacto/: 400 Client Error: Bad Request for url: https://www.ecp.ec/contacto/
# Error en https://www.colegiomenor.edu.ec/es/contact-us: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/contact-us
# Error en https://www.casc.edu.ec/directorio/: HTTPSConnectionPool(host='www.casc.edu.ec', port=443): Max retries exceeded with url: /directorio/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Buscando: institución educativa ecuador email
# Error en https://www.gob.ec/mineduc: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   + ► Correo Institucional Mail.educacion.gob.ec Outlook: 2 correos
# Error en https://www.gob.ec/mineduc/tramites/emision-autorizacion-creacion-funcionamiento-instituciones-educativas-particulares-fiscomisionales-municipales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://educacion.quito.gob.ec/: HTTPSConnectionPool(host='educacion.quito.gob.ec', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.tramitesbasicos.com/correo-institucional-ministerio-educacion/: 403 Client Error: Forbidden for url: https://www.tramitesbasicos.com/correo-institucional-ministerio-educacion/
# Error en https://twitter.com/ComunicacionEc/status/1401690861327597573: 400 Client Error: Bad Request for url: https://x.com/ComunicacionEc/status/1401690861327597573
# Buscando: colegios bilingües ecuador contacto
#   + Unidad Educativa Bilingue Surcos: 2 correos
# Error en https://www.uebi.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.uebi.edu.ec/
# Error en https://www.colegiomenor.edu.ec/es: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es
#   + Colegio Bilingüe En Quito: 1 correos
#   + Liceo Campo Verde: 1 correos
# Error en https://www.ibo.org/es/school/004348: HTTPSConnectionPool(host='www.ibo.org', port=443): Max retries exceeded with url: /es/school/004348 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://sekquito.com/: HTTPSConnectionPool(host='sekquito.com', port=443): Read timed out. (read timeout=10)
# Error en https://torremar.edu.ec/: 403 Client Error: Forbidden for url: https://torremar.edu.ec/
# Error en https://www.williamcaxton.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.williamcaxton.edu.ec/
# Buscando: colegio católico ecuador correo electrónico
#   + Colegio Católico José Engling: 5 correos
# Error en https://colegiomarieclarac.edu.ec/: 406 Client Error: Not Acceptable for url: https://colegiomarieclarac.edu.ec/
# Error en https://www.catholicvirtual.com/es/for-parents-and-students/: 403 Client Error: Forbidden for url: https://www.catholicvirtual.com/es/for-parents-and-students/
# Buscando: colegio privado ecuador contacto
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
#   + Colegio Privado Isaac Newton Al Norte De Quito: 5 correos
# Error en https://ilinizas.edu.ec/: 406 Client Error: Not Acceptable for url: https://ilinizas.edu.ec/
# Error en https://www.colegiomenor.edu.ec/es/about-us: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/about-us
#   + Colegio Cervantes: 1 correos
# Error en https://pachamama.edu.ec/: 406 Client Error: Not Acceptable for url: https://pachamama.edu.ec/
# Buscando: escuela pública ecuador correo
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/2019/10/directorio_telefonico-institucional-.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.gob.ec/mineduc/tramites/inscripcion-al-sistema-educativo-fiscal: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.gob.ec/mineduc/tramites/aprobacion-ejecucion-investigaciones-sistema-nacional-educacion: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.tramitesbasicos.com/correo-institucional-ministerio-educacion/: 403 Client Error: Forbidden for url: https://www.tramitesbasicos.com/correo-institucional-ministerio-educacion/
# Error en https://www.salud.gob.ec/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.educacionsuperior.gob.ec/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Buscando: colegios urbanos ecuador email
# Error en https://www.educacionsuperior.gob.ec/directorio-de-instituciones-de-educacion-superior/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.colegiomenor.edu.ec/es/contact-us: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/contact-us
# Error en https://www.ministeriodegobierno.gob.ec/seguridad-y-control-en-escuelas-y-colegios-en-la-region-costa-se-refuerza/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.unicef.org/ecuador/comunicados-prensa/1-de-cada-5-estudiantes-ha-sufrido-de-acoso-escolar-en-el-ecuador: 403 Client Error: Forbidden for url: https://www.unicef.org/ecuador/comunicados-prensa/1-de-cada-5-estudiantes-ha-sufrido-de-acoso-escolar-en-el-ecuador
# Error en https://www.infancia.gob.ec/colegio-replica-mejia-se-inauguro-al-sur-de-quito/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://scholar.google.com/scholar?q=colegios+urbanos+ecuador+email&hl=es&as_sdt=0&as_vis=1&oi=scholart: 403 Client Error: Forbidden for url: https://scholar.google.com/scholar?q=colegios+urbanos+ecuador+email&hl=es&as_sdt=0&as_vis=1&oi=scholart
# Error en https://www.quito.gob.ec/: HTTPSConnectionPool(host='www.quito.gob.ec', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Buscando: colegios rurales ecuador email contacto
# Error en https://familiasenruta.com/familias-crianza/visitando-una-escuelita-rural-en-ecuador/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.agricultura.gob.ec/inician-inscripciones-para-la-octava-edicion-de-la-escuela-joven-rural/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://unsdg.un.org/es/latest/stories/un-regreso-seguro-las-clases-presenciales-en-las-zonas-rurales-de-ecuador: 403 Client Error: Forbidden for url: https://unsdg.un.org/es/latest/stories/un-regreso-seguro-las-clases-presenciales-en-las-zonas-rurales-de-ecuador
# Error en https://www.vicepresidencia.gob.ec/parroquias-rurales-de-cuenca-se-benefician-con-reapertura-de-escuelas/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://es.wfp.org/noticias/ecuador-santa-elena-y-wfp-apuestan-por-las-comidas-escolares-nutritivas-en-escuelas-rurales: 403 Client Error: Forbidden for url: https://es.wfp.org/noticias/ecuador-santa-elena-y-wfp-apuestan-por-las-comidas-escolares-nutritivas-en-escuelas-rurales
# Error en https://ecuadorchequea.com/11-escuelas-rurales-de-imbabura-reciben-progresivamente-a-sus-estudiantes/: 406 Client Error: Not Acceptable for url: https://ecuadorchequea.com/11-escuelas-rurales-de-imbabura-reciben-progresivamente-a-sus-estudiantes/
# Error en https://ecuadorverifica.org/2022/05/25/guillermo-lasso-hemos-reabierto-100-escuelas-rurales/: 406 Client Error: Not Acceptable for url: https://ecuadorverifica.org/2022/05/25/guillermo-lasso-hemos-reabierto-100-escuelas-rurales/
# Error en https://es.wfp.org/noticias/el-programa-mundial-de-alimentos-inicia-la-entrega-de-comidas-escolares-en-escuelas: 403 Client Error: Forbidden for url: https://es.wfp.org/noticias/el-programa-mundial-de-alimentos-inicia-la-entrega-de-comidas-escolares-en-escuelas
# Error en https://rus.ucf.edu.cu/index.php/rus/article/view/2584: HTTPSConnectionPool(host='rus.ucf.edu.cu', port=443): Max retries exceeded with url: /index.php/rus/article/view/2584 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f7625ff1810>, 'Connection to rus.ucf.edu.cu timed out. (connect timeout=10)'))
# Error en https://www.researchgate.net/publication/335032589_Criticism_of_the_logical_positivism_of_the_rural_school_in_Ecuador: 403 Client Error: Forbidden for url: https://www.researchgate.net/publication/335032589_Criticism_of_the_logical_positivism_of_the_rural_school_in_Ecuador
# Buscando: unidad educativa particular ecuador email
# Error en https://www.uneindelpacifico.edu.ec/contacto/: 406 Client Error: Not Acceptable for url: https://www.uneindelpacifico.edu.ec/contacto/
#   + Inicio: 1 correos
# Error en https://ladolorosa.edu.ec/contacto/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://cedfi.com.ec/: 406 Client Error: Not Acceptable for url: https://cedfi.com.ec/
#   + Unidad Educativa Particular Porvenir: 1 correos
# Buscando: colegios con email de contacto ecuador
# Error en /search?num=22: Invalid URL '/search?num=22': No scheme supplied. Perhaps you meant https:///search?num=22?
# Error en https://sekquito.com/contacto/: HTTPSConnectionPool(host='sekquito.com', port=443): Read timed out. (read timeout=10)
# Error en https://www.casc.edu.ec/directorio/: HTTPSConnectionPool(host='www.casc.edu.ec', port=443): Max retries exceeded with url: /directorio/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.colegiomenor.edu.ec/es/contact-us: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/contact-us
# Error en https://sekguayaquil.com/contacto/: HTTPSConnectionPool(host='sekguayaquil.com', port=443): Read timed out. (read timeout=10)
# Error en https://seklosvalles.ec/contacto/: HTTPSConnectionPool(host='seklosvalles.ec', port=443): Read timed out. (read timeout=10)
#   + Directorio Instituciones: 3 correos
# Error en https://becquerel.edu.ec/contacto/: 403 Client Error: Forbidden for url: https://becquerel.edu.ec/contacto/
# Error en https://einstein.k12.ec/contact/: 403 Client Error: Forbidden for url: https://einstein.k12.ec/contact/
# Error en https://www.logosacademy.edu.ec/logos-academy-contacto-guayaquil/: 403 Client Error: Forbidden for url: https://www.logosacademy.edu.ec/logos-academy-contacto-guayaquil/
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
# Buscando: escuelas con email de contacto ecuador
# Error en /search?num=22: Invalid URL '/search?num=22': No scheme supplied. Perhaps you meant https:///search?num=22?
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/downloads/2014/09/Directorio-IES-2014.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.casc.edu.ec/directorio/: HTTPSConnectionPool(host='www.casc.edu.ec', port=443): Max retries exceeded with url: /directorio/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://seklosvalles.ec/contacto/: HTTPSConnectionPool(host='seklosvalles.ec', port=443): Read timed out. (read timeout=10)
# Error en https://www.independientedelvalle.com/escuelas-idv-sierra/: 403 Client Error: Forbidden for url: https://www.independientedelvalle.com/escuelas-idv-sierra/
# Error en https://www.educacionsuperior.gob.ec/directorio-de-instituciones-de-educacion-superior/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://sekguayaquil.com/: HTTPSConnectionPool(host='sekguayaquil.com', port=443): Read timed out. (read timeout=10)
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
# Buscando: colegios bilingües privados ecuador correo
# Error en https://www.colegiomenor.edu.ec/es: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es
# Error en https://sekquito.com/: HTTPSConnectionPool(host='sekquito.com', port=443): Read timed out. (read timeout=10)
# Error en https://www.uebi.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.uebi.edu.ec/
#   + Unidad Educativa Bilingüe "computer World": 1 correos
# Error en https://torremar.edu.ec/: 403 Client Error: Forbidden for url: https://torremar.edu.ec/
# Buscando: colegio secundario ecuador contacto email
#   + Colegio Menor: 6 correos
# Error en https://sekguayaquil.com/: HTTPSConnectionPool(host='sekguayaquil.com', port=443): Read timed out. (read timeout=10)
#   + Colegio Johannes Kepler: 1 correos
#   + Admisiones Secundaria: 2 correos
#   + Colegio La Moderna: 1 correos
# Error en https://sekquito.com/contacto/: HTTPSConnectionPool(host='sekquito.com', port=443): Read timed out. (read timeout=10)
# Error en https://www.colegiomenor.edu.ec/es: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es
# Buscando: colegio primaria ecuador email
# Error en https://www.casc.edu.ec/primaria/: HTTPSConnectionPool(host='www.casc.edu.ec', port=443): Max retries exceeded with url: /primaria/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Unidad Educativa Praga: 1 correos
# Error en https://www.colegiomenor.edu.ec/es/samborondon/academic-excellence/lower-school: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/samborondon/academic-excellence/lower-school
# Buscando: colegio técnico ecuador correo electrónico
# Error en https://www.lusha.com/business/67c8127bfdfc958f/: 403 Client Error: Forbidden for url: https://www.lusha.com/business/67c8127bfdfc958f/
# Error en https://x.com/colegioitse: 400 Client Error: Bad Request for url: https://x.com/colegioitse
# Error en https://uets.edu.ec/contactanos/: 406 Client Error: Not Acceptable for url: https://uets.edu.ec/contactanos/
# Error en https://uets.edu.ec/: 406 Client Error: Not Acceptable for url: https://uets.edu.ec/
# Error en https://www.gob.ec/mineduc/tramites/pase-transferencia-estudiantes-instituciones-educativas-fiscales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Buscando: colegio religioso ecuador contacto email
#   + Unidad Educativa Particular Nazaret: 1 correos
# Error en https://colegiomarieclarac.edu.ec/: 406 Client Error: Not Acceptable for url: https://colegiomarieclarac.edu.ec/
# Error en https://www.catholicvirtual.com/es/for-parents-and-students/: 403 Client Error: Forbidden for url: https://www.catholicvirtual.com/es/for-parents-and-students/
# Error en https://www.sagradafamiliacuenca.com/: HTTPSConnectionPool(host='www.sagradafamiliacuenca.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#   + Sscc: 2 correos
# Error en https://www.catholicvirtual.com/es/: 403 Client Error: Forbidden for url: https://www.catholicvirtual.com/es/
# Buscando: colegios oficiales ecuador email
# Error en https://www.gob.ec/mineduc/tramites/promocion-estudiantes-instituciones-educativas-fiscales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.gob.ec/mineduc/tramites/pase-transferencia-estudiantes-instituciones-educativas-fiscales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.comil14.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.comil14.edu.ec/
# Error en https://www.cali.gov.co/educacion/publicaciones/159761/directorio-ieo/: 403 Client Error: Forbidden for url: https://www.cali.gov.co/educacion/publicaciones/159761/directorio-ieo/
# Error en https://creconcepcion.cl/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Buscando: colegios católicos ecuador correo electrónico
#   + Red De Colegios Y Unidades Educativas De La Compañía De Jesús En El Ecuador Archives: 1 correos
# Error en https://www.catholicvirtual.com/es/: 403 Client Error: Forbidden for url: https://www.catholicvirtual.com/es/
# Error en https://colegiomarieclarac.edu.ec/: 406 Client Error: Not Acceptable for url: https://colegiomarieclarac.edu.ec/
# Error en https://www.catholicvirtual.com/es/for-parents-and-students/: 403 Client Error: Forbidden for url: https://www.catholicvirtual.com/es/for-parents-and-students/
#   + Quiénes Somos: 2 correos
# Error en https://inmaculada.edu.ec/: HTTPSConnectionPool(host='inmaculada.edu.ec', port=443): Read timed out. (read timeout=10)
# Error en https://sociedaddebeneficencia.org/unidades-educativas/: 403 Client Error: Forbidden for url: https://sociedaddebeneficencia.org/unidades-educativas/
# Buscando: colegios privados en quito email
# Error en https://www.colegiosquito.com/directorio-colegios-quito/: 403 Client Error: Forbidden for url: https://www.colegiosquito.com/directorio-colegios-quito/
# Error en https://www.liceointernacional.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.liceointernacional.edu.ec/
#   + Unidad Educativa Jason Miller: 1 correos
#   + Colegio Cristiano En Quito / Colegio Particular En Quito: 1 correos
# Error en https://ladolorosa.edu.ec/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.colegiomenor.edu.ec/es/contact-us: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/contact-us
# Buscando: colegios privados en guayaquil contacto email
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
# Error en https://www.santistevan.edu.ec/contacto: HTTPSConnectionPool(host='www.santistevan.edu.ec', port=443): Max retries exceeded with url: /contacto (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error en https://www.colegiomenor.edu.ec/es/samborondon: 429 Client Error: Too Many Requests for url: https://www.colegiomenor.edu.ec/es/samborondon
# Buscando: unidad educativa rural ecuador correo electrónico
# Error en https://unidadeducativaruminahui.org/: 406 Client Error: Not Acceptable for url: https://unidadeducativaruminahui.org/
# Error en https://www.agricultura.gob.ec/inician-inscripciones-para-la-octava-edicion-de-la-escuela-joven-rural/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.cali.gov.co/educacion/publicaciones/159761/directorio-ieo/: 403 Client Error: Forbidden for url: https://www.cali.gov.co/educacion/publicaciones/159761/directorio-ieo/
# Error en https://help.unhcr.org/ecuador/wp-content/uploads/sites/34/2021/04/Contactos-Distritos.pdf: 403 Client Error: Forbidden for url: https://help.unhcr.org/ecuador/wp-content/uploads/sites/34/2021/04/Contactos-Distritos.pdf
# Error en https://www.feyalegria.org.ec/centros/: HTTPSConnectionPool(host='www.feyalegria.org.ec', port=443): Read timed out. (read timeout=10)
# Error en https://www.salud.gob.ec/convocatoria-para-el-ano-de-salud-rural-en-unidades-de-salud-con-problemas-de-accesibilidad-a-los-servicios-integrales/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   + Sistematización De Experiencias De La Intervención Pedagógica Rural En Segundo Año De Educación General Básica Subnivel Elemental En La Unidad Educativa Pedro José Arteta, Distrito Educativo Lectivo: 1 correos
# Error en https://dominiodelasciencias.com/ojs/index.php/es/article/view/1765: HTTPSConnectionPool(host='dominiodelasciencias.com', port=443): Read timed out. (read timeout=10)
#   + Frecuencia De Helmintiosis Intestinales En Menores De Ños De Una Unidad Educativa Rural. Ecuador: 1 correos
# Error en https://scholar.google.es/citations?user=hpKveMgAAAAJ&hl=es: 403 Client Error: Forbidden for url: https://scholar.google.es/citations?user=hpKveMgAAAAJ&hl=es
# Buscando: colegio con correo oficial ecuador
# Error en https://sekguayaquil.com/: 500 Server Error: Internal Server Error for url: https://sekguayaquil.com/
# Error en https://www.americanschool.edu.ec/: 406 Client Error: Not Acceptable for url: https://www.americanschool.edu.ec/
# Error en https://pachamama.edu.ec/: 406 Client Error: Not Acceptable for url: https://pachamama.edu.ec/
# Error en https://ilinizas.edu.ec/: 406 Client Error: Not Acceptable for url: https://ilinizas.edu.ec/
#   + Colegio De Liga: 1 correos
# Buscando: institución educativa con email contacto ecuador
# Error en https://www.educacionsuperior.gob.ec/wp-content/uploads/2019/10/directorio_telefonico-institucional-.pdf: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.educacionsuperior.gob.ec/directorio-de-instituciones-de-educacion-superior/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.evaluacion.gob.ec/: HTTPSConnectionPool(host='www.evaluacion.gob.ec', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f7624914e10>, 'Connection to www.evaluacion.gob.ec timed out. (connect timeout=10)'))
# Error en https://www.gob.ec/mineduc: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://institucioncamsuizo.edu.ec/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error en https://www.gob.ec/mineduc/tramites/emision-autorizacion-creacion-funcionamiento-instituciones-educativas-particulares-fiscomisionales-municipales: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Total resultados: 41
#
# Archivo 'colegios_ecuador.json' guardado con éxito.
# /content/colegios_ecuador.json
# Ejemplo de resultados (10 primeros):
# {
#   "nombre": "Nombre no encontrado",
#   "correos": "cbonilla@colegiodeliga.edu.ec, cflores@colegiodeliga.edu.ec, fcabascango@colegiodeliga.edu.ec, jnaranjo@colegiodeliga.edu.ec, mesadeayuda@colegiodeliga.edu.ec, secretariageneral@colegiodeliga.edu.ec, vvaca@colegiodeliga.edu.ec, info@colegioterranova.edu.ec, info@seneca.edu.ec, administracion@seneca.edu.ec, inspeccion@colegiodeamerica.edu.ec, secretaria@colegiodeamerica.edu.ec, colecturia@colegiodeamerica.edu.ec, trabajosocial@colegiodeamerica.edu.ec, info@sanagustin.edu.ec, admisiones@sanagustin.edu.ec, n@colrosarioquito.edu.ec, rosarista@colrosario.edu.ec, informacion@colrosarioquito.edu.ec, info@thomasmore.edu.ec, magui.montalvo@soyamericalatina.edu.ec, maribel.quinteros@soyamericalatina.edu.ec, admisiones@ceeal.edu.ec, colecturia@soyamericalatina.edu.ec, uep@copol.edu.ec, colecturia@copol.edu.ec, admisiones@copol.edu.ec, asistentederectorado@copol.edu.ec, admisiones@williamthomsoninternacional.edu.ec, secretaria@ue25demarzo.edu.ec, coordinacion@aseccbi.edu.ec, secretaria@sagradocorazontdosantos.edu.ec"
# }
# {
#   "nombre": "Y Ubicación",
#   "correos": "adquisiciones@caq.edu.ec, almacen@caq.edu.ec, analista.compensaciones@caq.edu.ec, analista.seleccion@caq.edu.ec, apple.helpdesk@caq.edu.ec, asistente.gerencia@caq.edu.ec, asistente.recgeneral@caq.edu.ec, asistente.secundaria@caq.edu.ec, biblioteca@caq.edu.ec, cobranzas@caq.edu.ec, content.manager@caq.edu.ec, coordinador.transporte@caq.edu.ec, dpto.medico@caq.edu.ec, enfermeria.kinder@caq.edu.ec, extracurricular@caq.edu.ec, help.desk@caq.edu.ec, info@caq.edu.ec, jefe.comunicacion@caq.edu.ec, jefe.personal@caq.edu.ec, jefe.seguridad@caq.edu.ec, musica_cultura@caq.edu.ec, recepcion@caq.edu.ec, secretaria.kinder@caq.edu.ec, secretaria.primaria@caq.edu.ec, secretaria.secundaria@caq.edu.ec, seleccion@caq.edu.ec, tecnico.helpdesk@caq.edu.ec"
# }
# {
#   "nombre": "Contáctenos",
#   "correos": "contacto@csgabriel.edu.ec, info@uepgregoriano.edu.ec"
# }
# {
#   "nombre": "Contact Us",
#   "correos": "admision@espol.edu.ec, comunicacion@espol.edu.ec, espae@espol.edu.ec, fundespol@espol.edu.ec, info.cenaim@espol.edu.ec, kealvear@espol.edu.ec, postgrad@espol.edu.ec, relex@espol.edu.ec, transparencia@espol.edu.ec"
# }
# {
#   "nombre": "Colegio Terranova",
#   "correos": "ksalas@colegioterranova.edu.ec"
# }
# {
#   "nombre": "Escuela Politécnica Nacional",
#   "correos": "info@epn.edu.ec"
# }
# {
#   "nombre": "Https",
#   "correos": "secretaria@ueees.edu.ec"
# }
# {
#   "nombre": "Ue San José",
#   "correos": "uesanjosemilagro@uesanjose.edu.ec"
# }
# {
#   "nombre": "Unidad Educativa Santo Domingo De Guzmán",
#   "correos": "comunicacion@stodomingo.edu.ec"
# }
# {
#   "nombre": "Unidad Educativa A Distancia República De Argentina",
#   "correos": "administracion@ueargentina.edu.ec"
# }
